# %%
username = input("Type your name here: ")
color = input("Type your favourite color here: ")
food = input("Type your favourite food here: ")
hobby = input("Type your favourite hobby here: ")

print("Greetings, ", username, ".\nYour favourite color is ", color, ", your favourite hobby is ", hobby, " and your favourite food is ", food, ".", sep="")

spirit_animal = input("Type what is your spirit animal here: ")
print("Your spirit animal is ", spirit_animal, ". It fits you.", sep="")
